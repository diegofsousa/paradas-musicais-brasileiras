# %%
# importando as libs
import pandas as pd
import numpy as np
import requests as req
from selenium import webdriver
from scrapy.selector import Selector as scp
import json

# %%
dsm = pd.read_csv('musica_tophits_00.htm.csv', delimiter=';', header=None)
dsm
# Out:
#                                            0  \
# 0                            Amor I Love You
# 1            Se Eu Não Te Amasse Tanto Assim
# 2                                     Smooth
# 3                               Xibom Bombom
# 4                    Tô Te Filmando (Sorria)
# 5                          What A Girl Wants
# 6                                 Anna Julia
# 7                                      Music
# 8                                    El Arbi
# 9                       Minha Razão de Viver
# 10                               Maria Maria
# 11                             Vai Dar Samba
# 12                        I Knew I Loved You
# 13                            Demorô (remix)
# 14                         Shape Of My Heart
# 15                                 Separação
# 16                          A Dor Desse Amor
# 17                            Papo de Jacaré
# 18                               Face Oculta
# 19       Show Me The Meaning Of Broken Heart
# 20                          Pensando em Você
# 21                               Bye Bye Bye
# 22                        Você Virou Saudade
# 23                             I Turn To You
# 24                       Esperando na Janela
# 25                                Devolva-me
# 26                                   Rock DJ
# 27                      Nada Me Faz Esquecer
# 28                                 Colombina
# 29                                    Holler
# ..                                       ...
# 70                    Lady (Hear Me Tonight)
# 71                                 Primavera
# 72                                  Ojos Asi
# 73                              Tudo Que Vai
# 74                                   If Only
# 75                        (Mucho Mambo) Sway
# 76                              You're My #1
# 77                               Back At One
# 78              Estare Prendido En Tus Dedos
# 79                            Tchan na Selva
# 80                     Primavera (Vai Chuva)
# 81                                   Sexbomb
# 82                             Beautiful Day
# 83                         O Amor em Pedaços
# 84                Da Boca Pra Fora (ao vivo)
# 85                    Shackless (Praise You)
# 86                                   Desafio
# 87                                 Vai Pirar
# 88                          It's Gonna Be Me
# 89                      That's The Way It Is
# 90                                Breathless
# 91                                  Tua Boca
# 92                               Cordeirinho
# 93                             Amor Selvagem
# 94  Against All Odds (Take A Look At Me Now)
# 95                                   Tic-Bom
# 96                                 Lembrança
# 97                              Learn To Fly
# 98                       Painted On My Heart
# 99                        This I Promise You
#
#                                               1
# 0                            Marisa Monte (EMI)
# 1                     Ivete Sangalo (Universal)
# 2                Santana feat. Rob Thomas (BMG)
# 3                        As Meninas (Universal)
# 4                    Os Travessos (Continental)
# 5                      Christina Aguilera (BMG)
# 6                          Los Hermanos (Abril)
# 7                              Madonna (Warner)
# 8                            Khaled (Universal)
# 9                               Ara Ketu (Sony)
# 10          Santana feat. The Product G&B (BMG)
# 11                         Daniel (Continental)
# 12                         Savage Garden (Sony)
# 13                          Hannah Lima (Abril)
# 14                     Backstreet Boys (Virgin)
# 15                             Casa Nossa (RDS)
# 16                                   KLB (Sony)
# 17                             P.O. Box (Abril)
# 18                              Ara Ketu (Sony)
# 19                     Backstreet Boys (Virgin)
# 20                     Maurício Manieri (Abril)
# 21                             'N Sync (Virgin)
# 22                      Só Pra Contrariar (BMG)
# 23                     Christina Aguilera (BMG)
# 24                  Cogumelo Plutão (Universal)
# 25                    Adriana Calcanhotto (BMG)
# 26                     Robbie Williams (Virgin)
# 27                        Pepê & Neném (Virgin)
# 28                         Ed Motta (Universal)
# 29                         Spice Girls (Virgin)
# ..                                          ...
# 70                            Modjo (Universal)
# 71                         Los Hermanos (Abril)
# 72                               Shakira (Sony)
# 73                      Capital Inicial (Abril)
# 74                           Hanson (Universal)
# 75                            Shaft (Universal)
# 76  Enrique Iglesias/Sandy & Junior (Universal)
# 77   Brian McKnight & Ivete Sangalo (Universal)
# 78                                 Skank (Sony)
# 79                        É o Tchan (Universal)
# 80                     Maurício Manieri (Abril)
# 81        Tom Jones with Mousse T. (Roadrunner)
# 82                               U2 (Universal)
# 83                         Rita Lee (Universal)
# 84             Zezé Di Camargo & Luciano (Sony)
# 85                             Mary Mary (Sony)
# 86                                   Belo (EMI)
# 87         Jigaboo & Charlie Brown Jr. (Virgin)
# 88                             'N Sync (Virgin)
# 89                           Celine Dion (Sony)
# 90                        The Corrs (Universal)
# 91                                   Belo (EMI)
# 92                       Os Morenos (Universal)
# 93             Zezé Di Camargo & Luciano (Sony)
# 94                          Mariah Carey (Sony)
# 95                      Bom Balanço (Universal)
# 96                     Só no Sapatinho (Warner)
# 97                           Foo Fighters (BMG)
# 98                         The Cult (Universal)
# 99                             'N Sync (Virgin)
#
# [100 rows x 2 columns]

# %%
for linha in dsm.iterrows():
    str_de_busca = "'{} {}' site:www.letras.mus.br".format(linha[1][0], linha[1][1])
    str_de_busca = str_de_busca.replace("&","")
    print(str_de_busca)
    driver = webdriver.PhantomJS()
    try:
        driver.get("https://duckduckgo.com/?q=" + str_de_busca)
        #print(scp(text=driver.page_source).xpath('//a[@class="result__a"]/@href').extract())
    
        buscando_link = scp(text=driver.page_source).xpath('//a[@class="result__a"]/@href').extract_first()
        print(buscando_link)
        buscando_link = buscando_link.replace("traducao.html","")
    except:
        pass
    r = req.get(buscando_link)
    if r.status_code == 200:
        texto = r.content
        #print(texto)
        letra_aux = scp(text=texto).xpath('//div[@class="cnt-letra p402_premium"]/article/p/text()').extract()
        qtd_palavras_unicas = len(list(set(' '.join(letra_aux).lower().split(' '))))
        #print(scp(text=texto).xpath('//div[@class="cnt-info_exib"]/b/text()').extract_first())
        qtd_exibicoes = scp(text=texto).xpath('//div[@class="cnt-info_exib"]/b/text()').extract_first()
        qtd_exibicoes = int(qtd_exibicoes.replace('.',''))
        genero = scp(text=texto).xpath('//div[@id="breadcrumb"]/span/a/span/text()').extract()[1]
        if qtd_palavras_unicas > 1:
            print("{}, {}, {}".format(linha[1][0], qtd_palavras_unicas, qtd_exibicoes))
    else:
        print("Não achou link")
# Out:
# 'Amor I Love You Marisa Monte (EMI)' site:www.letras.mus.br
# https://www.letras.mus.br/marisa-monte/47268/
# Amor I Love You, 110, 1974459
# 'Se Eu Não Te Amasse Tanto Assim Ivete Sangalo (Universal)' site:www.letras.mus.br
# https://www.letras.mus.br/ivete-sangalo/35008/
# Se Eu Não Te Amasse Tanto Assim, 69, 2258075
# 'Smooth Santana feat. Rob Thomas (BMG)' site:www.letras.mus.br
# https://www.letras.mus.br/rob-thomas/804925/traducao.html
# Smooth, 105, 82405
# 'Xibom Bombom As Meninas (Universal)' site:www.letras.mus.br
# https://www.letras.mus.br/as-meninas/44262/
# Xibom Bombom, 64, 271973
# 'Tô Te Filmando (Sorria) Os Travessos (Continental)' site:www.letras.mus.br
# https://www.letras.mus.br/os-travessos/47859/
# Tô Te Filmando (Sorria), 72, 780156
# 'What A Girl Wants Christina Aguilera (BMG)' site:www.letras.mus.br
# https://www.letras.mus.br/christina-aguilera/79709/
# What A Girl Wants, 157, 46688
# 'Anna Julia Los Hermanos (Abril)' site:www.letras.mus.br
# https://www.letras.mus.br/los-hermanos/17958/
# Anna Julia, 88, 1692957
# 'Music Madonna (Warner)' site:www.letras.mus.br
# https://www.letras.mus.br/madonna/discografia/
# 'El Arbi Khaled (Universal)' site:www.letras.mus.br
# https://www.letras.mus.br/khaled/132908/
# El Arbi, 29, 118631
# 'Minha Razão de Viver Ara Ketu (Sony)' site:www.letras.mus.br
# https://www.letras.mus.br/araketu/44183/
# Minha Razão de Viver, 112, 475934
# 'Maria Maria Santana feat. The Product GB (BMG)' site:www.letras.mus.br
# https://www.letras.mus.br/santana/35045/traducao.html
# Maria Maria, 154, 96511
# 'Vai Dar Samba Daniel (Continental)' site:www.letras.mus.br
# https://www.letras.mus.br/daniel/45395/
# Vai Dar Samba, 68, 26363
# 'I Knew I Loved You Savage Garden (Sony)' site:www.letras.mus.br
# https://www.letras.mus.br/savage-garden/35140/
# I Knew I Loved You, 75, 151219
# 'Demorô (remix) Hannah Lima (Abril)' site:www.letras.mus.br
# https://www.letras.mus.br/michael-jackson/154276/
# Demorô (remix), 237, 11773
# 'Shape Of My Heart Backstreet Boys (Virgin)' site:www.letras.mus.br
# https://www.letras.mus.br/backstreet-boys/2806/
# Shape Of My Heart, 93, 158383
# 'Separação Casa Nossa (RDS)' site:www.letras.mus.br
# https://www.letras.mus.br/casa-nossa/44909/
# Separação, 84, 29114
# 'A Dor Desse Amor KLB (Sony)' site:www.letras.mus.br
# https://www.letras.mus.br/klb/46839/
# A Dor Desse Amor, 94, 535142
# 'Papo de Jacaré P.O. Box (Abril)' site:www.letras.mus.br
# https://www.letras.mus.br/po-box/47892/
# Papo de Jacaré, 133, 285164
# 'Face Oculta Ara Ketu (Sony)' site:www.letras.mus.br
# https://www.letras.mus.br/araketu/44178/
# Face Oculta, 93, 123068
# 'Show Me The Meaning Of Broken Heart Backstreet Boys (Virgin)' site:www.letras.mus.br
# https://www.letras.mus.br/backstreet-boys/2795/
# Show Me The Meaning Of Broken Heart, 96, 162070
# 'Pensando em Você Maurício Manieri (Abril)' site:www.letras.mus.br
# https://www.letras.mus.br/mauricio-manieri/47358/
# Pensando em Você, 64, 83960
# 'Bye Bye Bye 'N Sync (Virgin)' site:www.letras.mus.br
# https://www.letras.mus.br/nsync/63459/
# Bye Bye Bye, 120, 163514
# 'Você Virou Saudade Só Pra Contrariar (BMG)' site:www.letras.mus.br
# https://www.letras.mus.br/so-pra-contrariar/209629/
# Você Virou Saudade, 109, 212612
# 'I Turn To You Christina Aguilera (BMG)' site:www.letras.mus.br
# https://www.letras.mus.br/christina-aguilera/79688/
# I Turn To You, 94, 300942
# 'Esperando na Janela Cogumelo Plutão (Universal)' site:www.letras.mus.br
# https://www.letras.mus.br/membros/3659888/top_musicas.html
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-07e352cc10f4> in <module>()
#      21         #print(scp(text=texto).xpath('//div[@class="cnt-info_exib"]/b/text()').extract_first())
#      22         qtd_exibicoes = scp(text=texto).xpath('//div[@class="cnt-info_exib"]/b/text()').extract_first()
# ---> 23         qtd_exibicoes = int(qtd_exibicoes.replace('.',''))
#      24         genero = scp(text=texto).xpath('//div[@id="breadcrumb"]/span/a/span/text()').extract()[1]
#      25         if qtd_palavras_unicas > 1:
#
# AttributeError: 'NoneType' object has no attribute 'replace'
